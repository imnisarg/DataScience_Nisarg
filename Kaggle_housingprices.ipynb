# %%
import pandas as pd

# %%
data=pd.read_csv(r'''G:\kaggle\abc\train.csv''')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
data.shape
colsToDrop=[['SalePrice']]
y=data['SalePrice']
X=data.drop(['SalePrice'],axis=1)
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
X_train.shape
# Out:
# (1095, 80)

# %%
X_test.shape
# Out:
# (365, 80)

# %%
y_train.shape
# Out:
# (1095,)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
MSZoningEncoder = LabelEncoder()

StreetEncoder = LabelEncoder()
LotShapeEncoder=LabelEncoder()
SaleTypeEncoder=LabelEncoder()
SaleConditionEncoder=LabelEncoder()

# %%
X_train["MSZoning"] = MSZoningEncoder.fit_transform(X_train["MSZoning"].fillna("Nan"))

X_train["Street"] = StreetEncoder.fit_transform(X_train["Street"].fillna("Nan"))
X_train["LotShape"] =LotShapeEncoder.fit_transform(X_train["LotShape"].fillna("Nan"))
X_train["SaleType"] = SaleTypeEncoder.fit_transform(X_train["SaleType"].fillna("Nan"))
X_train["SaleCondition"] =SaleConditionEncoder.fit_transform(X_train["SaleCondition"].fillna("Nan"))
X_test["MSZoning"] = MSZoningEncoder.fit_transform(X_test["MSZoning"].fillna("Nan"))

X_test["Street"] = StreetEncoder.fit_transform(X_test["Street"].fillna("Nan"))
X_test["LotShape"] =LotShapeEncoder.fit_transform(X_test["LotShape"].fillna("Nan"))
X_test["SaleType"] = SaleTypeEncoder.fit_transform(X_test["SaleType"].fillna("Nan"))
X_test["SaleCondition"] =SaleConditionEncoder.fit_transform(X_test["SaleCondition"].fillna("Nan"))
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
X_train_final=X_train[['LotFrontage','LotArea','OverallQual','OverallCond','YrSold','MSZoning','Street','LotShape','SaleType','SaleCondition']]

# %%
X_test_final=X_test[['LotFrontage','LotArea','OverallQual','OverallCond','YrSold','MSZoning','Street','LotShape','SaleType','SaleCondition']]

# %%
X_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1095 entries, 1292 to 684
# Data columns (total 10 columns):
# LotFrontage      896 non-null float64
# LotArea          1095 non-null int64
# OverallQual      1095 non-null int64
# OverallCond      1095 non-null int64
# YrSold           1095 non-null int64
# MSZoning         1095 non-null int64
# Street           1095 non-null int64
# LotShape         1095 non-null int64
# SaleType         1095 non-null int64
# SaleCondition    1095 non-null int64
# dtypes: float64(1), int64(9)
# memory usage: 94.1 KB

# %%
X_train_final.isnull().values.any()
# Out:
# True

# %%
X_test_final.isnull().values.any()
# Out:
# True

# %%
X_train_final.isnull().any()
# Out:
# LotFrontage       True
# LotArea          False
# OverallQual      False
# OverallCond      False
# YrSold           False
# MSZoning         False
# Street           False
# LotShape         False
# SaleType         False
# SaleCondition    False
# dtype: bool

# %%
X_train_final["LotFrontage"].fillna(X_train_final.LotFrontage.mean(), inplace=True)
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
X_train_final.isnull().any()
# Out:
# LotFrontage      False
# LotArea          False
# OverallQual      False
# OverallCond      False
# YrSold           False
# MSZoning         False
# Street           False
# LotShape         False
# SaleType         False
# SaleCondition    False
# dtype: bool

# %%
X_test_final.isnull().any()
# Out:
# LotFrontage       True
# LotArea          False
# OverallQual      False
# OverallCond      False
# YrSold           False
# MSZoning         False
# Street           False
# LotShape         False
# SaleType         False
# SaleCondition    False
# dtype: bool

# %%
X_test_final["LotFrontage"].fillna(X_test_final.LotFrontage.mean(), inplace=True)
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
X_train_final
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YrSold  MSZoning  \
# 1292    60.000000     6600            5            4    2009         4
# 1018    69.764509    10784            7            5    2007         3
# 1213    69.764509    10246            4            9    2006         3
# 1430    60.000000    21930            5            5    2006         3
# 810     78.000000    10140            6            6    2006         3
# 477    105.000000    13693            9            5    2007         3
# 874     52.000000     5720            5            6    2009         4
# 505     60.000000     7596            5            5    2009         4
# 1418    71.000000     9204            5            5    2008         3
# 634     64.000000     6979            6            5    2010         3
# 1337   153.000000     4118            4            4    2006         4
# 752     79.000000     9236            6            5    2006         3
# ...

# %%
X_test_final
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YrSold  MSZoning  \
# 529     70.888525    32668            6            3    2007         3
# 491     79.000000     9490            6            7    2006         3
# 459     70.888525     7015            5            4    2009         3
# 279     83.000000    10005            7            5    2008         3
# 655     21.000000     1680            6            5    2010         4
# 1013    60.000000     7200            5            4    2009         4
# 1403    49.000000    15256            8            5    2007         3
# 601     50.000000     9000            6            6    2007         4
# 1182   160.000000    15623           10            5    2007         3
# 687     70.888525     5105            7            5    2007         1
# 1317    47.000000     4230            7            5    2007         1
# 1003    70.888525    11500            5            6    2007         3
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(data,x_vars=['LotFrontage','LotArea','OverallQual','OverallCond','YrSold','MSZoning','Street','LotShape','SaleType','SaleCondition'],y_vars='SalePrice',size=7,aspect=0.7,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-0081888a4a9d> in <module>()
# ----> 1 sns.pairplot(data,x_vars=['LotFrontage','LotArea','OverallQual','OverallCond','YrSold','MSZoning','Street','LotShape','SaleType','SaleCondition'],y_vars='SalePrice',size=7,aspect=0.7,kind='reg')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2074     elif kind == "reg":
#    2075         from .regression import regplot  # Avoid circular import
# -> 2076         plotter(regplot, **plot_kws)
#    2077
#    2078     # Add a legend
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
# ...

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge().fit(X_train_final, y_train)

# %%
print("training set score: %f" % ridge.score(X_train_final, y_train))
# Out:
# training set score: 0.690406

# %%
print("test set score: %f" % ridge.score(X_test_final, y_test))
# Out:
# test set score: 0.644477

# %%
ridge10 = Ridge(alpha=10).fit(X_train_final, y_train)
print("training set score: %f" % ridge10.score(X_train_final, y_train))
print("test set score: %f" % ridge10.score(X_test_final, y_test))
# Out:
# training set score: 0.689856
# test set score: 0.644181

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train_final, y_train)
print("training set score: %f" % ridge01.score(X_train_final, y_train))
print("test set score: %f" % ridge01.score(X_test_final, y_test))
# Out:
# training set score: 0.690446
# test set score: 0.644489

# %%
from sklearn.neural_network import MLPRegressor

# %%
clf = MLPRegressor()

# %%
clf.fit(X_train_final, y_train)
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
print("training set score: %f" % clf.score(X_train_final, y_train))
print("test set score: %f" % clf.score(X_test_final, y_test))
# Out:
# training set score: -0.197148
# test set score: -0.147593

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
housing_prices=gnb.fit(X_train_final,y_train)

# %%
print("training set score: %f" % gnb.score(X_train_final, y_train))
print("test set score: %f" % gnb.score(X_test_final, y_test))
# Out:
# training set score: 0.500457
# test set score: 0.008219

# %%
df=pd.read_csv(r'''G:\kaggle\abc\test.csv''')

# %%
XY=df[['LotFrontage','LotArea','OverallQual','OverallCond','YrSold','MSZoning','Street','LotShape','SaleType','SaleCondition']]

# %%
XY
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YrSold MSZoning Street  \
# 0            80.0    11622            5            6    2010       RH   Pave
# 1            81.0    14267            6            6    2010       RL   Pave
# 2            74.0    13830            5            5    2010       RL   Pave
# 3            78.0     9978            6            6    2010       RL   Pave
# 4            43.0     5005            8            5    2010       RL   Pave
# 5            75.0    10000            6            5    2010       RL   Pave
# 6             NaN     7980            6            7    2010       RL   Pave
# 7            63.0     8402            6            5    2010       RL   Pave
# 8            85.0    10176            7            5    2010       RL   Pave
# 9            70.0     8400            4            5    2010       RL   Pave
# 10           26.0     5858            7            5    2010       RH   Pave
# ...

# %%
XY.isnull().any()
# Out:
# LotFrontage       True
# LotArea          False
# OverallQual      False
# OverallCond      False
# YrSold           False
# MSZoning          True
# Street           False
# LotShape         False
# SaleType          True
# SaleCondition    False
# dtype: bool

# %%
XY["MSZoning"] = MSZoningEncoder.fit_transform(XY["MSZoning"].fillna("Nan"))

XY["Street"] = StreetEncoder.fit_transform(XY["Street"].fillna("Nan"))
XY["LotShape"] =LotShapeEncoder.fit_transform(XY["LotShape"].fillna("Nan"))
XY["SaleType"] = SaleTypeEncoder.fit_transform(XY["SaleType"].fillna("Nan"))
XY["SaleCondition"] =SaleConditionEncoder.fit_transform(XY["SaleCondition"].fillna("Nan"))
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
XY
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YrSold  MSZoning  \
# 0            80.0    11622            5            6    2010         3
# 1            81.0    14267            6            6    2010         4
# 2            74.0    13830            5            5    2010         4
# 3            78.0     9978            6            6    2010         4
# 4            43.0     5005            8            5    2010         4
# 5            75.0    10000            6            5    2010         4
# 6             NaN     7980            6            7    2010         4
# 7            63.0     8402            6            5    2010         4
# 8            85.0    10176            7            5    2010         4
# 9            70.0     8400            4            5    2010         4
# 10           26.0     5858            7            5    2010         3
# 11           21.0     1680            6            5    2010         5
# ...

# %%
XY.isnull().any()
# Out:
# LotFrontage       True
# LotArea          False
# OverallQual      False
# OverallCond      False
# YrSold           False
# MSZoning         False
# Street           False
# LotShape         False
# SaleType         False
# SaleCondition    False
# dtype: bool

# %%
XY["LotFrontage"].fillna(XY.LotFrontage.mean(), inplace=True)
# Out:
# C:\Users\NISARG\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
XY
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YrSold  MSZoning  \
# 0       80.000000    11622            5            6    2010         3
# 1       81.000000    14267            6            6    2010         4
# 2       74.000000    13830            5            5    2010         4
# 3       78.000000     9978            6            6    2010         4
# 4       43.000000     5005            8            5    2010         4
# 5       75.000000    10000            6            5    2010         4
# 6       68.580357     7980            6            7    2010         4
# 7       63.000000     8402            6            5    2010         4
# 8       85.000000    10176            7            5    2010         4
# 9       70.000000     8400            4            5    2010         4
# 10      26.000000     5858            7            5    2010         3
# 11      21.000000     1680            6            5    2010         5
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR = GradientBoostingRegressor(n_estimators=100, max_depth=4)
GBR.fit(X_train_final, y_train)
GBR.score(X_test_final,y_test)
y_pred=GBR.predict(XY)

# %%
y_pred
# Out:
# array([142355.75394491, 210756.55245237, 150952.3864751 , ...,
#        152205.39105525, 120997.25314281, 176807.55412432])

# %%
ids=df[['Id']]

# %%
ids
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# 5     1466
# 6     1467
# 7     1468
# 8     1469
# 9     1470
# 10    1471
# 11    1472
# 12    1473
# 13    1474
# 14    1475
# 15    1476
# 16    1477
# 17    1478
# 18    1479
# 19    1480
# 20    1481
# 21    1482
# 22    1483
# 23    1484
# 24    1485
# 25    1486
# 26    1487
# 27    1488
# 28    1489
# 29    1490
# ...    ...
# 1429  2890
# 1430  2891
# 1431  2892
# 1432  2893
# 1433  2894
# 1434  2895
# 1435  2896
# 1436  2897
# 1437  2898
# 1438  2899
# 1439  2900
# 1440  2901
# 1441  2902
# 1442  2903
# 1443  2904
# 1444  2905
# 1445  2906
# 1446  2907
# 1447  2908
# 1448  2909
# 1449  2910
# 1450  2911
# 1451  2912
# 1452  2913
# 1453  2914
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
pd.DataFrame(ids).to_csv(r'''G:\kaggle\abc\mysub6.csv''',index=None,mode='a')

# %%
pd.DataFrame(y_pred).to_csv(r'''G:\kaggle\abc\mysub6.csv''',index=None,mode='a')
